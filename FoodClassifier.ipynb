# %% [markdown]
# # 0. Installing

# %%
# clone YOLOv5 repository
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# !pip install -qr requirements.txt  # install dependencies (ignore errors)

import torch
from IPython.display import Image, clear_output  # to display images

device = torch.cuda.get_device_name() if torch.cuda.is_available() else 'CPU'
print(f'Using torch {torch.__version__},  {device}')
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 14997, done.
# remote: Total 14997 (delta 0), reused 0 (delta 0), pack-reused 14997
# Receiving objects: 100% (14997/14997), 14.01 MiB | 16.64 MiB/s, done.
# Resolving deltas: 100% (10299/10299), done.
# /content/yolov5
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.0/184.0 KB 2.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 814.7 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 39.3 MB/s eta 0:00:00
# Using torch 1.13.0+cu116,  Tesla T4

# %% [markdown]
# # 1. Custom dataset

# %%
from google.colab import files
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# !ls "/content/drive/My Drive/deltahacks"
# !cd "/content/drive/My Drive/train_data"
# !mv train_data drive
# !unzip "/content/drive/My Drive/deltahacks" train_data.zip
# Out:
# FoodClassifier.ipynb  train_data.zip
# mv: cannot stat 'train_data': No such file or directory

# %% [markdown]
# # 1. Training
# https://www.youtube.com/watch?v=GRtgLlwxpc4

# %%
# Train YOLOv5s on custom dataset for X epochs
# !python train.py --img 640 --batch 16 --epochs 1500 --data food_data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=food_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=1500, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-69-g3b6e27a Python-3.8.16 torch-1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %% [markdown]
# # 2. Results

# %% [markdown]
# # 3. Prediction

# %% [markdown]
# # 4. Exporting model

# %%
files.download('./runs/train/exp/weights/best.pt')
